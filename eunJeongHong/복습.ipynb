# %%
#리스트
score=[]
print(score)
score=[56,90,67,89,20,83,75,99]
score.sort()
print(score)
if score < 50 :
    score.remove()
    print(score)
# Out:
# []
# [20, 56, 67, 75, 83, 89, 90, 99]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 7
#       3 print(score)
#       4 score=[56,90,67,89,20,83,75,99]
#       5 score.sort()
#       6 print(score)
# ----> 7 if score < 50 :
#       8     score.remove()
#       9 print(score)
#      10
#
# TypeError: '<' not supported between instances of 'list' and 'int'
